# %%
# http://127.0.0.1:8888/?token=d8645dfa36d67d3f2ca03610ce0c3c8e01cc36bd6dfab090
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
from jupyterthemes import jtplot
jtplot.style(theme='chesterish')
% matplotlib inline

# %% [markdown]
# # XGBoost
# ***

# %%
model_name = 'xgb'
append_info = 'xgb_increase_postscale'
param_name = 'lr'
param_values = [0.003]
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
marker_list = ['_', 'x', '>', ',', '=']
data = []
labels = []

idx = 1
train_seed = 999
cv_seed = 95
for param_value in param_values:
    data.append(pd.read_csv('../boost_round_outputs/' + model_name + '/' 
                            + model_name + '_'+ append_info + '/'
                            + model_name + '_'+ param_name + '/'
                            + model_name + '_'+ param_name+ '-' + str(param_value) 
                            + '/final_logs/' + model_name + '_idx-' + str(idx) 
                            + '_t-'+ str(train_seed) + '_c-' + str(cv_seed) + '_log.csv'))
    labels.append(param_name + '-' + str(param_value) + '-' + str(idx))

# append_info = 'forward_increase_weights'
# for param_value in param_values:
#     data.append(pd.read_csv('../boost_round_outputs/' + model_name + '/' 
#                             + model_name + '_'+ append_info + '/'
#                             + model_name + '_'+ param_name + '/'
#                             + model_name + '_'+ param_name+ '-' + str(param_value) 
#                             + '/final_logs/' + model_name + '_idx-' + str(idx) 
#                             + '_t-'+ str(train_seed) + '_c-' + str(cv_seed) + '_log.csv'))
#     labels.append(param_name + '-' + str(param_value) + '-' + str(idx))   
    
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
i_marker = -1
i_color = 0
for i, label in enumerate(labels):
    if (i)%(len(param_values)) == 0:
        i_marker += 1
        i_color = 0
    ax.plot(data[i]['valid_loss'], color=color[i_color], label=label, marker=marker_list[i_marker])
    i_color += 1
ax.legend(loc='best')
# plt.ylim(0.6908, 0.6912)
# plt.xlim(100, 150)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %% [markdown]
# ## max_depth
# ***

# %%
model_name = 'xgb'
append_info = 'xgb_increase_postscale'
# append_info = 'forward_window'
param_name = 'bfq'
param_values = [1, 3, 5, 7, 9, 11]
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
marker_list = ['_', 'x', '>', ',', '=']
data = []
labels = []

idx = 1
train_seed = 66
cv_seed = 113
for param_value in param_values:
    data.append(pd.read_csv('../boost_round_outputs/lgb/lgb_'+ append_info 
                            + '/lgb_'+ param_name+ 
                            '/lgb_'+ param_name+ '-' + str(param_value) 
                            + '/final_logs/lgb_idx-' + str(idx) 
                            + '_t-'+ str(train_seed) + '_c-' + str(cv_seed) + '_log.csv'))
    labels.append(param_name + '-' + str(param_value) + '-' + str(idx))
    
# idx = 2
# train_seed = 634
# cv_seed = 614
# for param_value in param_values:
#     data.append(pd.read_csv('../boost_round_outputs/lgb/lgb_'+ append_info 
#                             + '/lgb_'+ param_name+ 
#                             '/lgb_'+ param_name+ '-' + str(param_value) 
#                             + '/final_logs/lgb_idx-' + str(idx) 
#                             + '_t-'+ str(train_seed) + '_c-' + str(cv_seed) + '_log.csv'))
#     labels.append(param_name + '-' + str(param_value) + '-' + str(idx))
    
# idx = 3
# train_seed = 547
# cv_seed = 707
# for param_value in param_values:
#     data.append(pd.read_csv('../boost_round_outputs/lgb/lgb_'+ append_info 
#                             + '/lgb_'+ param_name+ 
#                             '/lgb_'+ param_name+ '-' + str(param_value) 
#                             + '/final_logs/lgb_idx-' + str(idx) 
#                             + '_t-'+ str(train_seed) + '_c-' + str(cv_seed) + '_log.csv'))
#     labels.append(param_name + '-' + str(param_value) + '-' + str(idx))

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
i_marker = -1
i_color = 0
for i, label in enumerate(labels):
    if (i)%(len(param_values)) == 0:
        i_marker += 1
        i_color = 0
    ax.plot(data[i]['valid_loss'], color=color[i_color], label=label, marker=marker_list[i_marker])
    i_color += 1
ax.legend(loc='best')
# plt.ylim(0.6908, 0.6912)
# plt.xlim(100, 150)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
i_marker = -1
i_color = 0
for i, label in enumerate(labels):
    if (i)%(len(param_values)) == 0:
        i_marker += 1
        i_color = 0
    ax.plot(data[i]['train_loss'], color=color[i_color], label=label, marker=marker_list[i_marker])
    i_color += 1
ax.legend(loc='best')
# plt.ylim(0.665, 0.680)
# plt.xlim(100, 150)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
idx = 2
train_seed = 634
cv_seed = 614
data = []
labels = []
for param_value in param_values:
    data.append(pd.read_csv('../boost_round_outputs/lgb/lgb_'+ append_info 
                            + '/lgb_'+ param_name+ 
                            '/lgb_'+ param_name+ '-' + str(param_value) 
                            + '/final_logs/lgb_idx-' + str(idx) 
                            + '_t-'+ str(train_seed) + '_c-' + str(cv_seed) + '_log.csv'))
    labels.append(param_name + '-' + str(param_value) + '-' + str(idx))

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
i_marker = -1
i_color = 0
for i, label in enumerate(labels):
    if (i)%(len(param_values)) == 0:
        i_marker += 1
        i_color = 0
    ax.plot(data[i]['valid_loss'], color=color[i_color], label=label, marker=marker_list[i_marker])
    i_color += 1
ax.legend(loc='best')
# plt.ylim(0.6908, 0.6912)
# plt.xlim(100, 150)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
idx = 3
train_seed = 547
cv_seed = 707
data = []
labels = []
for param_value in param_values:
    data.append(pd.read_csv('../boost_round_outputs/lgb/lgb_'+ append_info 
                            + '/lgb_'+ param_name+ 
                            '/lgb_'+ param_name+ '-' + str(param_value) 
                            + '/final_logs/lgb_idx-' + str(idx) 
                            + '_t-'+ str(train_seed) + '_c-' + str(cv_seed) + '_log.csv'))
    labels.append(param_name + '-' + str(param_value) + '-' + str(idx))
    
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
i_marker = -1
i_color = 0
for i, label in enumerate(labels):
    if (i)%(len(param_values)) == 0:
        i_marker += 1
        i_color = 0
    ax.plot(data[i]['valid_loss'], color=color[i_color], label=label, marker=marker_list[i_marker])
    i_color += 1
ax.legend(loc='best')
# plt.ylim(0.6908, 0.6912)
# plt.xlim(100, 150)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %% [markdown]
# ## CV Parameters
# ***

# %%
model_name = 'xgb'
append_info = 'forward_window_postscale'

cv = (10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20,
      10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20,
      10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20,
      10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20,
      10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20, 10, 12, 15, 20)
vr = (0.1, 0.1, 0.1, 0.1, 0.2, 0.2, 0.2, 0.2, 0.125, 0.125, 0.125, 0.125, 0.166, 0.166, 0.166, 0.166,
      0.1, 0.1, 0.1, 0.1, 0.2, 0.2, 0.2, 0.2, 0.125, 0.125, 0.125, 0.125, 0.166, 0.166, 0.166, 0.166,
      0.1, 0.1, 0.1, 0.1, 0.2, 0.2, 0.2, 0.2, 0.125, 0.125, 0.125, 0.125, 0.166, 0.166, 0.166, 0.166,
      0.1, 0.1, 0.1, 0.1, 0.2, 0.2, 0.2, 0.2, 0.125, 0.125, 0.125, 0.125, 0.166, 0.166, 0.166, 0.166,
      0.1, 0.1, 0.1, 0.1, 0.2, 0.2, 0.2, 0.2, 0.125, 0.125, 0.125, 0.125, 0.166, 0.166, 0.166, 0.166)
ws = (32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32, 32,
      35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35, 35,
      40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40, 40,
      48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48, 48,
      60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60, 60)

color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray', 'pink']
marker_list = ['_', 'x', '>', ',', '=']
data = []
labels = []

idx = 1
train_seed = 999
cv_seed = 95
path = '../boost_round_outputs/' + model_name + '/' + model_name + '_'+ append_info + '/' + model_name + '_cv_vr_ws/'
last = '_t-'+ str(train_seed) + '_c-' + str(cv_seed) + '_log.csv'
data = []
label = []
for i in range(len(cv)):
    data.append(pd.read_csv(path + '' + model_name + '_cv-'+str(cv[i])+'_vr-'+str(vr[i])+'_ws-'+str(ws[i])
                            +'/final_logs/' + model_name + '_idx-1' + last))
    label.append('cv-'+str(cv[i])+'_vr-'+str(vr[i]) + '_ws-' + str(ws[i]))
    
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

delta = 0

i = 0 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i])
i = 1 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i])
i = 2 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i])
i = 3 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i])
i = 4 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='x')
i = 5 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='x')
i = 6 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='x')
i = 7 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='x')
i = 8 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='>')
i = 9 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='>')
i = 10 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='>')
i = 11 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='>')
i = 12 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='.')
i = 13 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='.')
i = 14 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='.')
i = 15 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='')

ax.legend(loc='best')
# plt.ylim(0.691, 0.698)
# plt.xlim(0, 125)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

delta = 16

i = 0 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='_')
i = 1 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='_')
i = 2 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='_')
i = 3 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='_')
i = 4 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='x')
i = 5 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='x')
i = 6 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='x')
i = 7 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='x')
i = 8 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='>')
i = 9 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='>')
i = 10 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='>')
i = 11 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='>')
i = 12 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='.')
i = 13 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='.')
i = 14 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='.')
i = 15 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='')

ax.legend(loc='best')
# plt.ylim(0.691, 0.698)
# plt.xlim(0, 125)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

delta = 32

i = 0 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='_')
i = 1 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='_')
i = 2 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='_')
i = 3 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='_')
i = 4 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker=',')
i = 5 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker=',')
i = 6 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker=',')
i = 7 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker=',')
i = 8 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='>')
i = 9 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='>')
i = 10 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='>')
i = 11 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='>')
i = 12 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='.')
i = 13 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='.')
i = 14 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='.')
i = 15 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='')

ax.legend(loc='best')
# plt.ylim(0.691, 0.698)
# plt.xlim(0, 125)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

delta = 48

i = 0 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='_')
i = 1 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='_')
i = 2 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='_')
i = 3 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='_')
i = 4 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='x')
i = 5 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='x')
i = 6 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='x')
i = 7 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='x')
i = 8 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='>')
i = 9 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='>')
i = 10 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='>')
i = 11 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='>')
i = 12 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='.')
i = 13 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='.')
i = 14 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='.')
i = 15 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='')

ax.legend(loc='best')
# plt.ylim(0.691, 0.698)
# plt.xlim(0, 125)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

delta = 64

i = 0 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='_')
i = 1 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='_')
i = 2 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='_')
i = 3 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='_')
i = 4 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='x')
i = 5 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='x')
i = 6 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='x')
i = 7 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='x')
i = 8 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='>')
i = 9 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='>')
i = 10 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='>')
i = 11 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='>')
i = 12 + delta
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i], marker='.')
i = 13 + delta
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i], marker='.')
i = 14 + delta
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i], marker='.')
i = 15 + delta
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i], marker='')

ax.legend(loc='best')
# plt.ylim(0.691, 0.698)
# plt.xlim(0, 125)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

i = 12
ax.plot(data[i]['valid_loss'], color=color[0], label=label[i])
i = 26
ax.plot(data[i]['valid_loss'], color=color[1], label=label[i])
i = 29
ax.plot(data[i]['valid_loss'], color=color[2], label=label[i])
i = 32
ax.plot(data[i]['valid_loss'], color=color[3], label=label[i])
i = 40
ax.plot(data[i]['valid_loss'], color=color[5], label=label[i])

ax.legend(loc='best')
plt.ylim(0.690, 0.692)
# plt.xlim(0, 125)
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()
