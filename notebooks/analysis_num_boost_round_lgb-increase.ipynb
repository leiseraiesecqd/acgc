# %%
# http://127.0.0.1:8888/?token=d8645dfa36d67d3f2ca03610ce0c3c8e01cc36bd6dfab090
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
% matplotlib inline

# %% [markdown]
# ## lgb
# ***

# %%
idx = 1
train_seed = 750
cv_seed = 543
unit_num_list = [0.001]
data = []
for i in range(len(unit_num_list)):
    data.append(pd.read_csv('../boost_round_outputs/lgb/lgb_increase_dynamic_cv-10/lgb_lr/lgb_lr-'
                            + str(unit_num_list[i]) + '/final_logs/lgb_idx-' + str(idx) 
                            + '_t-'+ str(train_seed) + '_c-' + str(cv_seed) + '_log.csv'))

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
for i in range(len(unit_num_list)):
    ax.plot(data[i]['valid_loss'], color=color[i], label=str(unit_num_list[i]))
ax.legend(loc='best')
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
for i in range(len(unit_num_list)):
    ax.plot(data[i]['train_loss'], color=color[i], label=str(unit_num_list[i]))
ax.legend(loc='best')
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
idx = 1
train_seed = 65
cv_seed = 241
unit_num_list = [
#                  [32, 16, 8], [64, 32, 16],
#                  [128, 64, 32, 16], [128, 64, 32], [128, 64], 
#                  [2048, 512],
                 [256, 128, 64, 32, 16], [256, 128, 64, 32], [256, 128, 64], [256, 128],
                 [200, 100, 50]
                ]
data = []
for i in range(len(unit_num_list)):
    data.append(pd.read_csv('./num_boost_rounds/dnn/dnn_unit_number_' + str(unit_num_list[i]) +
                '/final_logs/dnn_unit_number_' + str(unit_num_list[i]) + '_' 
                + str(idx) + '_t'+ str(train_seed) + '_c' + str(cv_seed) + '_log.csv'))

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
for i in range(len(unit_num_list)):
    ax.plot(data[i]['valid_loss'], color=color[i], label=str(unit_num_list[i]))
ax.legend(loc='best')
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-2705deda7bfe> in <module>()
#      13     data.append(pd.read_csv('./num_boost_rounds/dnn/dnn_unit_number_' + str(unit_num_list[i]) +
#      14                 '/final_logs/dnn_unit_number_' + str(unit_num_list[i]) + '_'
# ---> 15                 + str(idx) + '_t'+ str(train_seed) + '_c' + str(cv_seed) + '_log.csv'))
#      16
#      17 fig=plt.figure()
#
# ~/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     653                     skip_blank_lines=skip_blank_lines)
#     654
# --> 655         return _read(filepath_or_buffer, kwds)
#     656
#     657     parser_f.__name__ = name
#
# ~/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     403
#     404     # Create the parser.
# --> 405     parser = TextFileReader(filepath_or_buffer, **kwds)
#     406
#     407     if chunksize or iterator:
#
# ~/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     762             self.options['has_index_names'] = kwds['has_index_names']
#     763
# --> 764         self._make_engine(self.engine)
#     765
#     766     def close(self):
#
# ~/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     983     def _make_engine(self, engine='c'):
#     984         if engine == 'c':
# --> 985             self._engine = CParserWrapper(self.f, **self.options)
#     986         else:
#     987             if engine == 'python':
#
# ~/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1603         kwds['allow_leading_cols'] = self.index_col is not False
#    1604
# -> 1605         self._reader = parsers.TextReader(src, **kwds)
#    1606
#    1607         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__ (pandas/_libs/parsers.c:4209)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source (pandas/_libs/parsers.c:8873)()
#
# FileNotFoundError: File b'./num_boost_rounds/dnn/dnn_unit_number_[256, 128, 64, 32, 16]/final_logs/dnn_unit_number_[256, 128, 64, 32, 16]_1_t65_c241_log.csv' does not exist

# %%
idx = 1
train_seed = 65
cv_seed = 241
unit_num_list = [
                 [288, 144, 72], [288, 144, 72, 36],
                 [256, 128, 64], [256, 128, 64, 32],
                 [216, 108, 54], [216, 108, 54, 27]
                ]
data = []
for i in range(len(unit_num_list)):
    data.append(pd.read_csv('./num_boost_rounds/dnn/dnn_unit_number_' + str(unit_num_list[i]) +
                '/final_logs/dnn_unit_number_' + str(unit_num_list[i]) + '_' 
                + str(idx) + '_t'+ str(train_seed) + '_c' + str(cv_seed) + '_log.csv'))

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
for i in range(len(unit_num_list)):
    ax.plot(data[i]['valid_loss'], color=color[i], label=str(unit_num_list[i]))
ax.legend(loc='best')
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
idx = 1
train_seed = 65
cv_seed = 241
unit_num_list = [
                 [128, 256, 128, 64], [128, 256, 128], [256, 128, 64], [256, 128],
                 [64, 128, 64, 32], [64, 128, 64], [128, 64]
                ]
data = []
for i in range(len(unit_num_list)):
    data.append(pd.read_csv('./num_boost_rounds/dnn/dnn_unit_number_' + str(unit_num_list[i]) +
                '/final_logs/dnn_unit_number_' + str(unit_num_list[i]) + '_' 
                + str(idx) + '_t'+ str(train_seed) + '_c' + str(cv_seed) + '_log.csv'))

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
for i in range(len(unit_num_list)):
    ax.plot(data[i]['valid_loss'], color=color[i], label=str(unit_num_list[i]))
ax.legend(loc='best')
fig.set_figheight(15)
fig.set_figwidth(20)
plt.show()

# %%
idx = 1
train_seed = 65
cv_seed = 241
kee_prob_list = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
data = []
for i in range(len(kee_prob_list)):
    data.append(pd.read_csv('./num_boost_rounds/dnn/dnn_keep_probability_' + str(kee_prob_list[i]) +
                '/final_logs/dnn_keep_probability_' + str(kee_prob_list[i]) + '_' 
                + str(idx) + '_t'+ str(train_seed) + '_c' + str(cv_seed) + '_log.csv'))

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
for i in range(len(kee_prob_list)):
    ax.plot(data[i]['valid_loss'], color=color[i], label=str(kee_prob_list[i]))
ax.legend(loc='best')
fig.set_figheight(15)
fig.set_figwidth(20)
plt.xlim(0, 20)
plt.show()

# %%
idx = 1
train_seed = 65
cv_seed = 241
kee_prob_list = [0.4, 0.5, 0.6, 0.7, 0.8, 0.9]
data = []
for i in range(len(kee_prob_list)):
    data.append(pd.read_csv('./num_boost_rounds/dnn/dnn_keep_probability_' + str(kee_prob_list[i]) +
                '/final_logs/dnn_keep_probability_' + str(kee_prob_list[i]) + '_' 
                + str(idx) + '_t'+ str(train_seed) + '_c' + str(cv_seed) + '_log.csv'))

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
for i in range(len(kee_prob_list)):
    ax.plot(data[i]['train_loss'], color=color[i], label=str(kee_prob_list[i]))
ax.legend(loc='best')
fig.set_figheight(15)
fig.set_figwidth(20)
# plt.xlim(0, 20)
plt.show()

# %%
idx = 1
train_seed = 65
cv_seed = 241
learning_rate_list = [
#     0.00001,
    0.00001, 0.00003, 0.00004, 0.00005, 0.0001, 0.0003, 0.0005
]
data = []
for i in range(len(learning_rate_list)):
    data.append(pd.read_csv('./num_boost_rounds/dnn/dnn_learning_rate_' + str(learning_rate_list[i]) +
                '/final_logs/dnn_learning_rate_' + str(learning_rate_list[i]) + '_' 
                + str(idx) + '_t'+ str(train_seed) + '_c' + str(cv_seed) + '_log.csv'))

fig=plt.figure()
ax=fig.add_subplot(1,1,1)
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
for i in range(len(learning_rate_list)):
    ax.plot(data[i]['valid_loss'], color=color[i], label=str(learning_rate_list[i]))
ax.legend(loc='best')
fig.set_figheight(15)
fig.set_figwidth(20)
# plt.xlim(0, 20)
plt.show()

# %%
idx = 1
train_seed = 65
cv_seed = 241
data1 = pd.read_csv('./num_boost_rounds/dnn/dnn_learning_rate_2e-05/final_logs/dnn_learning_rate_2e-05_1_t65_c241_log.csv')
data2 = pd.read_csv('./num_boost_rounds/dnn/dnn_learning_rate_2e-05/final_logs/dnn_learning_rate_2e-05_2_t666_c216_log.csv')
fig=plt.figure()
ax=fig.add_subplot(1,1,1)
color = ['r', 'b', 'g', 'y', 'k', 'm', 'gray']
ax.plot(data1['valid_loss'], color=color[0], label='t65_c241')
ax.plot(data2['valid_loss'], color=color[1], label='t666_c216')
ax.legend(loc='best')
fig.set_figheight(15)
fig.set_figwidth(20)
# plt.xlim(0, 20)
plt.show()
